# %%
""" Los string permiten almacenar texto
    se pueden escribir con comillas, comillas simples o tres comillas """

s = "El libro de Python"
print (s)                   # El libro de Python
print (type(s))             # <class 'str'"

s = 'El libro de Python'
print ("""El libro
de
Python""")
